# %% [markdown]
# # H1 TITLE
# ## H2 TITLE

# %%
print("Buy the dip ?")
# Out:
# Buy the dip ?

# %%
import numpy as np
arr = np.array([
    10,
    3.14,
    "hello",
    {"a": 1},
    [1, 2],
    (1, 2),
    {1, 2},
    True
], dtype=object)
for i in arr:
    print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'bool'>

# %%
arr = np.zeros(300)
